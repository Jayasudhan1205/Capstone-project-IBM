# %% [markdown]
# # Battle of the Neighborhoods - Coursera Capstone Project
#
#
# ## INTRODUCTION
#
#
# ## In this project we will help people who are all looking to buy an apartment in New York city and they can find:
# #### Which borough has the highest sales and which BOROUGH has the lowest sales
# #### one can find out the price of the apartment in Gross square feet area wise and the Land square feet area.
# #### After finding the borough, one will be able to see which city in that borough has the highest sales and the analysis on the borough has been made in this project. This project will help people to choose Boroughs and to buy the apartment in the appropriate cities and this also helps people to explore the cities to find out the advantages and disadvantages with the help of kmeans clustering and the Four Squared location data set and  we also clustering the city.
#
#
# ## Data Acquisition and Cleaning
#
# #### The dataset used in this project has been acquired from kaggle dataset .This dataset is a record of every building or apartment sold in a New York city property market in 2017 over a period of 12 months.
#
# ## DATASET:
# #### This  contains the location, address, type, sales price  and sale date of building units sold and some of them are
# ## BOROUGH:
# #### A digit code for the borough the property is located in; in order these are Manhattan (1), Bronx (2), Brooklyn (3), Queens (4), and Staten Island (5).
# ## BLOCK; LOT:
# #### The combination of borough, block, and lot forms a unique key for property in New York City. Commonly called a BBL.
# ## BUILDING CLASS AT PRESENT and BUILDING CLASS AT TIME OF SALE:
# #### The type of building at various points in time. See the glossary linked to below.
#
# ## The dataset consists of 84548 rows and 22 columns
#
# # New York City Neighborhoods Dataset
#
# #### This city has total of 5 boroughs and 306 Neighborhoods. In order to segment the Neighborhoods and explore them, we will essentially need  a dataset that contains the 5 boroughs and the Neighborhoods that exists in each borough as well as the latitude and longitude coordinates of each Neighborhood.
#
# #### Luckily these dataset exist for free on the web. The link to the dataset : https://geo.nyu.edu/catalog/nyu_2451_34572
