# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/covid19_india.csv")

# %%
data.dtypes
# Out:
# Sno                          int64
# Date                        object
# Time                        object
# State/UnionTerritory        object
# ConfirmedIndianNational     object
# ConfirmedForeignNational    object
# Cured                        int64
# Deaths                       int64
# Confirmed                    int64
# dtype: object

# %%
data.head(10)
# Out:
#    Sno      Date     Time  ... Cured Deaths Confirmed
# 0    1  30/01/20  6:00 PM  ...     0      0         1
# 1    2  31/01/20  6:00 PM  ...     0      0         1
# 2    3  01/02/20  6:00 PM  ...     0      0         2
# 3    4  02/02/20  6:00 PM  ...     0      0         3
# 4    5  03/02/20  6:00 PM  ...     0      0         3
# 5    6  04/02/20  6:00 PM  ...     0      0         3
# 6    7  05/02/20  6:00 PM  ...     0      0         3
# 7    8  06/02/20  6:00 PM  ...     0      0         3
# 8    9  07/02/20  6:00 PM  ...     0      0         3
# 9   10  08/02/20  6:00 PM  ...     0      0         3
#
# [10 rows x 9 columns]

# %%
data.drop(['Time'], axis = 1,inplace = True)

# %%
data['Active'] = data['Confirmed'] - data['Cured'] - data['Deaths']

# %%
data.head(10)
# Out:
#    Sno      Date State/UnionTerritory  ... Deaths Confirmed  Active
# 0    1  30/01/20               Kerala  ...      0         1       1
# 1    2  31/01/20               Kerala  ...      0         1       1
# 2    3  01/02/20               Kerala  ...      0         2       2
# 3    4  02/02/20               Kerala  ...      0         3       3
# 4    5  03/02/20               Kerala  ...      0         3       3
# 5    6  04/02/20               Kerala  ...      0         3       3
# 6    7  05/02/20               Kerala  ...      0         3       3
# 7    8  06/02/20               Kerala  ...      0         3       3
# 8    9  07/02/20               Kerala  ...      0         3       3
# 9   10  08/02/20               Kerala  ...      0         3       3
#
# [10 rows x 9 columns]

# %%
 kerala = data[data['State/UnionTerritory']=='Kerala']

# %%
kerala.tail(50)
# Out:
#        Sno       Date State/UnionTerritory  ... Deaths Confirmed  Active
# 1237  1238 2020-04-23               Kerala  ...      3       438     111
# 1269  1270 2020-04-24               Kerala  ...      3       448     121
# 1301  1302 2020-04-25               Kerala  ...      4       451     116
# 1333  1334 2020-04-26               Kerala  ...      4       458     116
# 1365  1366 2020-04-27               Kerala  ...      4       469     123
# 1397  1398 2020-04-28               Kerala  ...      4       482     123
# 1429  1430 2020-04-29               Kerala  ...      4       486     123
# 1461  1462 2020-04-30               Kerala  ...      4       496     123
# 1493  1494 2020-01-05               Kerala  ...      4       497     110
# 1525  1526 2020-02-05               Kerala  ...      4       497     101
# 1557  1558 2020-03-05               Kerala  ...      4       500      96
# 1589  1590 2020-04-05               Kerala  ...      4       500      95
# ...

# %%
kerala['State/UnionTerritory'].unique()
# Out:
# array(['Kerala'], dtype=object)

# %%
kerala.drop(['Sno'], axis = 1, inplace =True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize =(40,40))
ax  = sns.barplot(x='Date',y='Active',data = kerala)
plt.title("Barplot of Active Cases Datewise for the state kerala",fontsize =40)
plt.xlabel('Date',fontsize =30)
plt.ylabel('Active',fontsize = 30)
# Out:
# Text(0, 0.5, 'Active')

# %%
active_cases = kerala['Active'].max()
active_cases
# Out:
# 1238

# %%
plt.figure(figsize=(40,40))
sns.barplot(x ='Date',y='Confirmed',data= kerala)
plt.title("Barplot of Confirmed cases Datewise for the state kerala",fontsize =40)
plt.xlabel('Date',fontsize =30)
plt.ylabel('Confirmed',fontsize = 30)
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
total_confirmed = kerala['Confirmed'].max()
total_confirmed
# Out:
# 2161

# %%
plt.figure(figsize=(40,40))
sns.barplot(x ='Date',y='Cured',data = kerala)
plt.title("Barplot of Cured cases Datewise for the state kerala",fontsize =40)
plt.xlabel('Date',fontsize =30)
plt.ylabel('Cured',fontsize = 30)
# Out:
# Text(0, 0.5, 'Cured')

# %%
total_cured = kerala['Cured'].max()
total_cured
# Out:
# 905

# %%
plt.figure(figsize=(40,40))
sns.barplot(x ='Date',y='Deaths',data =kerala)
plt.title("Barplot of Death cases Datewise for the state kerala",fontsize =40)
plt.xlabel('Date',fontsize =30)
plt.ylabel('Deaths',fontsize = 30)
# Out:
# Text(0, 0.5, 'Deaths')

# %%
total_deaths_kerala = kerala['Deaths'].max()
total_deaths_kerala
# Out:
# 18

# %%
kerala.head()
# Out:
#        Date State/UnionTerritory  ... Confirmed Active
# 0  30/01/20               Kerala  ...         1      1
# 1  31/01/20               Kerala  ...         1      1
# 2  01/02/20               Kerala  ...         2      2
# 3  02/02/20               Kerala  ...         3      3
# 4  03/02/20               Kerala  ...         3      3
#
# [5 rows x 8 columns]

# %%
kerala_active = kerala[['Date','Active']]
kerala_active.head()
# Out:
#        Date  Active
# 0  30/01/20       1
# 1  31/01/20       1
# 2  01/02/20       2
# 3  02/02/20       3
# 4  03/02/20       3

# %%
plt.figure(figsize=(10,8))
plt.scatter(kerala_active['Date'].tail(50),kerala_active['Active'].tail(50))
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.bar(kerala_active['Date'].tail(50),kerala_active['Active'].tail(50))
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(25,10))
plt.title('combined graph')
plt.xticks(rotation=90)
sns.pointplot(kerala['Date'],kerala['Active'],color='red')
sns.pointplot(kerala['Date'],kerala['Cured'],color='green')
sns.pointplot(kerala['Date'],kerala['Deaths'],color='black')
sns.pointplot(kerala['Date'],kerala['Confirmed'],color='yellow')
plt.xlabel('Dates',fontsize =15)
plt.ylabel('cases',fontsize =15)
plt.show()

# %%
kerala_confirmed = kerala[['Date','Confirmed']]
kerala_confirmed.head()
# Out:
#        Date  Confirmed
# 0  30/01/20          1
# 1  31/01/20          1
# 2  01/02/20          2
# 3  02/02/20          3
# 4  03/02/20          3

# %%
kerala_active.tail(17)
# Out:
#             ds     y
# 2322  26/05/20   359
# 2358  27/05/20   415
# 2394  28/05/20   445
# 2430  29/05/20   526
# 2466  30/05/20   577
# 2502  31/05/20   624
# 2538  01/06/20   670
# 2574  02/06/20   708
# 2610  03/06/20   774
# 2646  04/06/20   832
# 2682  05/06/20   884
# 2718  06/06/20   973
# 2754  07/06/20  1030
# 2790  08/06/20  1096
# 2826  09/06/20  1175
# 2862  10/06/20  1232
# 2899  11/06/20  1238

# %%
covid = pd.read_csv("/content/covid_19_india (2).csv")

# %%
covid_kerala['Active'].max()
# Out:
# 359

# %%
covid.head(50)
# Out:
#     Unnamed: 0        Date       State/UT  ...  Mortality rate  Cured  Recovery rate
# 0            0  2020/01/30         Kerala  ...             0.0      0            0.0
# 1            1  2020/01/31         Kerala  ...             0.0      0            0.0
# 2            2  2020/02/01         Kerala  ...             0.0      0            0.0
# 3            3  2020/02/02         Kerala  ...             0.0      0            0.0
# 4            4  2020/02/03         Kerala  ...             0.0      0            0.0
# 5            5  2020/02/04         Kerala  ...             0.0      0            0.0
# 6            6  2020/02/05         Kerala  ...             0.0      0            0.0
# 7            7  2020/02/06         Kerala  ...             0.0      0            0.0
# 8            8  2020/02/07         Kerala  ...             0.0      0            0.0
# 9            9  2020/02/08         Kerala  ...             0.0      0            0.0
# ...

# %%
covid_kerala= covid[covid['State/UT'] == 'Kerala']

# %%
covid_kerala.tail()
# Out:
#       Unnamed: 0        Date State/UT  ...  Mortality rate  Cured  Recovery rate
# 2167        2167  2020/05/22   Kerala  ...        0.005797    510       0.739130
# 2200        2200  2020/05/23   Kerala  ...        0.005464    512       0.699454
# 2233        2233  2020/05/24   Kerala  ...        0.005031    515       0.647799
# 2267        2267  2020/05/25   Kerala  ...        0.004723    521       0.615112
# 2301        2301  2020/05/26   Kerala  ...        0.005580    532       0.593750
#
# [5 rows x 11 columns]

# %%
covid_active = covid_kerala[['Date','Active']]

# %%
covid_active =covid_active.rename(columns ={'Date':'ds','Active':'y'})
covid_active.head(10)
# Out:
#            ds  y
# 0  2020/01/30  1
# 1  2020/01/31  1
# 2  2020/02/01  2
# 3  2020/02/02  3
# 4  2020/02/03  3
# 5  2020/02/04  3
# 6  2020/02/05  3
# 7  2020/02/06  3
# 8  2020/02/07  3
# 9  2020/02/08  3

# %%
from fbprophet import Prophet
#A library in python created by facebook for time-series forecasting
#We need two columns (first-Date(ds) , second-forecast_values(y))

# %%
model = Prophet()
model.fit(covid_active)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods = 15)
future.tail(15)
# Out:
#             ds
# 118 2020-05-27
# 119 2020-05-28
# 120 2020-05-29
# 121 2020-05-30
# 122 2020-05-31
# 123 2020-06-01
# 124 2020-06-02
# 125 2020-06-03
# 126 2020-06-04
# 127 2020-06-05
# 128 2020-06-06
# 129 2020-06-07
# 130 2020-06-08
# 131 2020-06-09
# 132 2020-06-10

# %%
forecast=model.predict(future)

# %%
forecast.tail(15)
# Out:
#             ds       trend  ...  multiplicative_terms_upper        yhat
# 118 2020-05-27  172.469626  ...                         0.0  166.941948
# 119 2020-05-28  173.748388  ...                         0.0  170.693846
# 120 2020-05-29  175.027150  ...                         0.0  172.929107
# 121 2020-05-30  176.305912  ...                         0.0  175.573984
# 122 2020-05-31  177.584674  ...                         0.0  180.415880
# 123 2020-06-01  178.863436  ...                         0.0  181.966759
# 124 2020-06-02  180.142198  ...                         0.0  185.619857
# 125 2020-06-03  181.420960  ...                         0.0  175.893282
# 126 2020-06-04  182.699722  ...                         0.0  179.645180
# 127 2020-06-05  183.978484  ...                         0.0  181.880441
# 128 2020-06-06  185.257246  ...                         0.0  184.525318
# 129 2020-06-07  186.536008  ...                         0.0  189.367214
# ...

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail(7)
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 126 2020-06-04  179.645180   85.307290  271.383059
# 127 2020-06-05  181.880441   85.620198  275.069285
# 128 2020-06-06  184.525318   89.052835  278.949613
# 129 2020-06-07  189.367214   92.516203  287.274283
# 130 2020-06-08  190.918093   95.787019  283.267094
# 131 2020-06-09  194.571191  104.156284  289.421674
# 132 2020-06-10  184.844616   89.678520  283.209940

# %%
active_plot=model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)

# %%
covid_Tamilnadu = covid[covid['State/UT'] == 'Tamil Nadu']

# %%
covid_Tamilnadu.head(10).reset_index()
covid_Tamilnadu.drop('Unnamed: 0',axis =1, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
covid_Tamilnadu.head()
# Out:
#            Date    State/UT  Latitude  ...  Mortality rate  Cured  Recovery rate
# 60   2020/03/07  Tamil Nadu   11.1271  ...             0.0      0            0.0
# 68   2020/03/08  Tamil Nadu   11.1271  ...             0.0      0            0.0
# 79   2020/03/09  Tamil Nadu   11.1271  ...             0.0      0            0.0
# 91   2020/03/10  Tamil Nadu   11.1271  ...             0.0      0            0.0
# 103  2020/03/11  Tamil Nadu   11.1271  ...             0.0      0            0.0
#
# [5 rows x 10 columns]

# %%
plt.figure(figsize = (20,20))
sns.barplot(x='Date',y='Active',data = covid_Tamilnadu)
plt.title("barplot for active cases in Tamil Nadu")
# Out:
# Text(0.5, 1.0, 'barplot for active cases in Tamil Nadu')

# %%
plt.figure(figsize = (20,20))
sns.barplot(x='Date',y ='Confirmed',data = covid_Tamilnadu)
plt.title("barplot for confirmed cases in TamilNadu")
# Out:
# Text(0.5, 1.0, 'barplot for confirmed cases in TamilNadu')

# %%
plt.figure(figsize = (20,20))
sns.barplot(x='Date',y ='Cured',data = covid_Tamilnadu)
plt.title("barplot for Cured cases in TamilNadu")
# Out:
# Text(0.5, 1.0, 'barplot for Cured cases in TamilNadu')

# %%
plt.figure(figsize = (20,20))
sns.barplot(x='Date',y ='Deaths',data = covid_Tamilnadu)
plt.title("barplot for Deaths  in TamilNadu")
# Out:
# Text(0.5, 1.0, 'barplot for Deaths  in TamilNadu')

# %%
plt.figure(figsize = (15,12))
sns.scatterplot(x='Date',y ='Active',data = covid_Tamilnadu)
plt.title("scatterplot for Active cases in TamilNadu")
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Text(0.5, 1.0, 'scatterplot for Active cases in TamilNadu')

# %%
import seaborn as sns

plt.figure(figsize=(25,10))
plt.title('combined graph')
plt.xticks(rotation=90)
sns.pointplot(covid_Tamilnadu['Date'],covid_Tamilnadu['Active'],color='red')
sns.pointplot(covid_Tamilnadu['Date'],covid_Tamilnadu['Cured'],color='green')
sns.pointplot(covid_Tamilnadu['Date'],covid_Tamilnadu['Deaths'],color='black')
sns.pointplot(covid_Tamilnadu['Date'],covid_Tamilnadu['Confirmed'],color='yellow')
plt.xlabel('Dates',fontsize =15)
plt.ylabel('cases',fontsize =15)
plt.show()

# %%
covid_Tamilnadu_active = covid_Tamilnadu[['Date','Active']].reset_index()

# %%
covid_Tamilnadu_active.drop('index',axis = 1, inplace =True)

# %%
covid_Tamilnadu_active = covid_Tamilnadu_active.rename(columns ={'df':'ds','Active':'y'})

# %%
covid_Tamilnadu_active.head()
# Out:
#            ds  y
# 0  2020/03/07  1
# 1  2020/03/08  1
# 2  2020/03/09  1
# 3  2020/03/10  1
# 4  2020/03/11  1

# %%
from fbprophet import Prophet
#A library in python created by facebook for time-series forecasting
#We need two columns (first-Date(ds) , second-forecast_values(y))

# %%
model = Prophet()
model.fit(covid_Tamilnadu_active)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods = 25)
future.tail(25)
# Out:
#             ds
# 81  2020-05-27
# 82  2020-05-28
# 83  2020-05-29
# 84  2020-05-30
# 85  2020-05-31
# 86  2020-06-01
# 87  2020-06-02
# 88  2020-06-03
# 89  2020-06-04
# 90  2020-06-05
# 91  2020-06-06
# 92  2020-06-07
# 93  2020-06-08
# 94  2020-06-09
# 95  2020-06-10
# 96  2020-06-11
# 97  2020-06-12
# 98  2020-06-13
# 99  2020-06-14
# 100 2020-06-15
# 101 2020-06-16
# 102 2020-06-17
# 103 2020-06-18
# 104 2020-06-19
# 105 2020-06-20

# %%
forecast=model.predict(future)

# %%
forecast.tail(25)
# Out:
#             ds         trend  ...  multiplicative_terms_upper          yhat
# 81  2020-05-27   9245.742131  ...                         0.0   9289.335672
# 82  2020-05-28   9535.422422  ...                         0.0   9570.373138
# 83  2020-05-29   9825.102713  ...                         0.0   9891.137308
# 84  2020-05-30  10114.783004  ...                         0.0  10148.948073
# 85  2020-05-31  10404.463295  ...                         0.0  10359.093502
# 86  2020-06-01  10694.143586  ...                         0.0  10602.562852
# 87  2020-06-02  10983.823877  ...                         0.0  10942.030485
# 88  2020-06-03  11273.504168  ...                         0.0  11317.097709
# 89  2020-06-04  11563.184459  ...                         0.0  11598.135175
# 90  2020-06-05  11852.864750  ...                         0.0  11918.899345
# 91  2020-06-06  12142.545041  ...                         0.0  12176.710110
# ...

# %%
active_plot=model.plot(forecast)

# %%
active_components=model.plot_components(forecast)

# %%
covid_Tamilnadu_confirmed = covid_Tamilnadu[['Date','Confirmed']].reset_index()
covid_Tamilnadu_confirmed.drop('index',axis =1,inplace = True)
covid_Tamilnadu_confirmed.head()
# Out:
#          Date  Confirmed
# 0  2020/03/07          1
# 1  2020/03/08          1
# 2  2020/03/09          1
# 3  2020/03/10          1
# 4  2020/03/11          1

# %%
covid_Tamilnadu_confirmed =covid_Tamilnadu_confirmed.rename(columns ={'Date':'ds','Confirmed':'y'})
covid_Tamilnadu_confirmed
# Out:
#             ds      y
# 0   2020/03/07      1
# 1   2020/03/08      1
# 2   2020/03/09      1
# 3   2020/03/10      1
# 4   2020/03/11      1
# ..         ...    ...
# 76  2020/05/22  13967
# 77  2020/05/23  14753
# 78  2020/05/24  15512
# 79  2020/05/25  16277
# 80  2020/05/26  17082
#
# [81 rows x 2 columns]

# %%
model = Prophet()
model.fit(covid_Tamilnadu_confirmed)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods = 25)
future.tail(25)
# Out:
#             ds
# 81  2020-05-27
# 82  2020-05-28
# 83  2020-05-29
# 84  2020-05-30
# 85  2020-05-31
# 86  2020-06-01
# 87  2020-06-02
# 88  2020-06-03
# 89  2020-06-04
# 90  2020-06-05
# 91  2020-06-06
# 92  2020-06-07
# 93  2020-06-08
# 94  2020-06-09
# 95  2020-06-10
# 96  2020-06-11
# 97  2020-06-12
# 98  2020-06-13
# 99  2020-06-14
# 100 2020-06-15
# 101 2020-06-16
# 102 2020-06-17
# 103 2020-06-18
# 104 2020-06-19
# 105 2020-06-20

# %%
forecast = model.predict(future)

# %%
forecast.tail(25)
# Out:
#             ds         trend  ...  multiplicative_terms_upper          yhat
# 81  2020-05-27  17185.300271  ...                         0.0  17183.328307
# 82  2020-05-28  17810.899892  ...                         0.0  17808.464598
# 83  2020-05-29  18436.499513  ...                         0.0  18430.237248
# 84  2020-05-30  19062.099134  ...                         0.0  19057.301193
# 85  2020-05-31  19687.698754  ...                         0.0  19671.334510
# 86  2020-06-01  20313.298375  ...                         0.0  20321.352641
# 87  2020-06-02  20938.897996  ...                         0.0  20962.675438
# 88  2020-06-03  21564.497617  ...                         0.0  21562.525652
# 89  2020-06-04  22190.097238  ...                         0.0  22187.661943
# 90  2020-06-05  22815.696858  ...                         0.0  22809.434594
# 91  2020-06-06  23441.296479  ...                         0.0  23436.498539
# ...

# %%
active_plot1 = model.plot(forecast)

# %%
active_components2=model.plot_components(forecast)

# %%
import plotly.express as px

# %%
india = covid.groupby('State/UT')['Confirmed'].sum().reset_index()

# %%
india.head(10)
# Out:
#                       State/UT  Confirmed
# 0  Andaman and Nicobar Islands       1378
# 1               Andhra Pradesh      73323
# 2            Arunachal Pradesh         55
# 3                        Assam       4111
# 4                        Bihar      32762
# 5                   Chandigarh       5139
# 6                 Chhattisgarh       3232
# 7           Dadar Nagar Haveli         24
# 8                        Delhi     259592
# 9                          Goa        827

# %%
india = covid.groupby('State/UT')['Confirmed','Active','Deaths'].sum().reset_index()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
india
# Out:
#                        State/UT  Confirmed  Active  Deaths
# 0   Andaman and Nicobar Islands       1378     363       0
# 1                Andhra Pradesh      73323   40507    1578
# 2             Arunachal Pradesh         55      20       0
# 3                         Assam       4111    2730      77
# 4                         Bihar      32762   21810     234
# 5                    Chandigarh       5139    3315      53
# 6                  Chhattisgarh       3232    1409       0
# 7            Dadar Nagar Haveli         24      24       0
# 8                         Delhi     259592  161286    4111
# 9                           Goa        827     482       0
# 10                      Gujarat     282032  174742   16138
# 11                      Haryana      26271   12094     343
# 12             Himachal Pradesh       3083    1515      98
# 13            Jammu and Kashmir      35855   21242     460
# 14                    Jharkhand       6113    3750     129
# ...

# %%
india_datewise = covid.groupby('Date')['Active','Confirmed','Deaths'].sum().reset_index()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
india_datewise.head()
# Out:
#          Date  Active  Confirmed  Deaths
# 0  2020/01/30       1          1       0
# 1  2020/01/31       1          1       0
# 2  2020/02/01       2          2       0
# 3  2020/02/02       3          3       0
# 4  2020/02/03       3          3       0

# %%
india_datewise_confirmed = india_datewise[['Date','Confirmed']]

# %%
india_datewise_confirmed =india_datewise_confirmed.rename(columns ={'Date':'ds','Confirmed':'y'})
india_datewise_confirmed.head()
# Out:
#            ds  y
# 0  2020/01/30  1
# 1  2020/01/31  1
# 2  2020/02/01  2
# 3  2020/02/02  3
# 4  2020/02/03  3

# %%
model = Prophet()
model.fit(india_datewise_confirmed)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods = 25)
future.tail(25)
# Out:
#             ds
# 118 2020-05-27
# 119 2020-05-28
# 120 2020-05-29
# 121 2020-05-30
# 122 2020-05-31
# 123 2020-06-01
# 124 2020-06-02
# 125 2020-06-03
# 126 2020-06-04
# 127 2020-06-05
# 128 2020-06-06
# 129 2020-06-07
# 130 2020-06-08
# 131 2020-06-09
# 132 2020-06-10
# 133 2020-06-11
# 134 2020-06-12
# 135 2020-06-13
# 136 2020-06-14
# 137 2020-06-15
# 138 2020-06-16
# 139 2020-06-17
# 140 2020-06-18
# 141 2020-06-19
# 142 2020-06-20

# %%
forecast = model.predict(future)

# %%
forecast.tail(25)
# Out:
#             ds          trend  ...  multiplicative_terms_upper           yhat
# 118 2020-05-27  136464.228262  ...                         0.0  136195.883876
# 119 2020-05-28  140604.703205  ...                         0.0  140373.403553
# 120 2020-05-29  144745.178147  ...                         0.0  144614.338587
# 121 2020-05-30  148885.653090  ...                         0.0  148870.714206
# 122 2020-05-31  153026.128033  ...                         0.0  153099.418311
# 123 2020-06-01  157166.602976  ...                         0.0  157387.966769
# 124 2020-06-02  161307.077919  ...                         0.0  161657.846330
# 125 2020-06-03  165447.552861  ...                         0.0  165179.208475
# 126 2020-06-04  169588.027804  ...                         0.0  169356.728153
# 127 2020-06-05  173728.502747  ...                         0.0  173597.663187
# 128 2020-06-06  177868.977690  ...                         0.0  177854.038806
# ...

# %%
active_plot = model.plot(forecast)

# %%
active_components = model.plot_components(forecast)
